# %%
from utility.utilities import read_excel_sheet

import os

# %%
src_dir = os.path.abspath(os.path.join(os.getcwd(), "."))

file_absolute_path_excel = os.path.join(src_dir, "data/NBA23-24.xlsx")

df = read_excel_sheet(file_absolute_path_excel, "StatsPerGame")

# %%
df.head(15)
# Out:
#     Rk                   Player  Age Team Pos   G  GS    MP    FG   FGA  ...  \
# 0    1              Joel Embiid   29  PHI   C  39  39  33.6  11.5  21.8  ...
# 1    2              Luka Dončić   24  DAL  PG  70  70  37.5  11.5  23.6  ...
# 2    3    Giannis Antetokounmpo   29  MIL  PF  73  73  35.2  11.5  18.8  ...
# 3    4  Shai Gilgeous-Alexander   25  OKC  PG  75  75  34.0  10.6  19.8  ...
# 4    5            Jalen Brunson   27  NYK  PG  77  77  35.4  10.3  21.4  ...
# 5    6             Devin Booker   27  PHO  PG  68  68  36.0   9.4  19.2  ...
# 6    7             Kevin Durant   35  PHO  PF  75  75  37.2  10.0  19.1  ...
# 7    8             Jayson Tatum   25  BOS  PF  74  74  35.7   9.1  19.3  ...
# 8    9             De'Aaron Fox   26  SAC  PG  74  74  35.9   9.7  20.9  ...
# 9   10         Donovan Mitchell   27  CLE  SG  55  55  35.3   9.1  19.8  ...
# 10  11            Stephen Curry   35  GSW  PG  74  74  32.7   8.8  19.5  ...
# 11  12             Nikola Jokić   28  DEN   C  79  79  34.6  10.4  17.9  ...
# 12  13          Anthony Edwards   22  MIN  SG  79  78  35.1   9.1  19.7  ...
# 13  14             Tyrese Maxey   23  PHI  PG  70  70  37.5   9.1  20.3  ...
# 14  15             LeBron James   39  LAL  PF  71  71  35.3   9.6  17.9  ...
#
#     ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  \
# 0   2.4  8.6  11.0  5.6  1.2  1.7  3.8  2.9  34.7
# 1   0.8  8.4   9.2  9.8  1.4  0.5  4.0  2.1  33.9
# 2   2.7  8.8  11.5  6.5  1.2  1.1  3.4  2.9  30.4
# 3   0.9  4.7   5.5  6.2  2.0  0.9  2.2  2.5  30.1
# 4   0.6  3.1   3.6  6.7  0.9  0.2  2.4  1.9  28.7
# 5   0.8  3.7   4.5  6.9  0.9  0.4  2.6  3.0  27.1
# 6   0.5  6.1   6.6  5.0  0.9  1.2  3.3  1.8  27.1
# 7   0.9  7.2   8.1  4.9  1.0  0.6  2.5  2.0  26.9
# 8   0.9  3.7   4.6  5.6  2.0  0.4  2.6  2.6  26.6
# 9   0.8  4.3   5.1  6.1  1.8  0.5  2.8  2.1  26.6
# 10  0.5  4.0   4.5  5.1  0.7  0.4  2.8  1.6  26.4
# 11  2.8  9.5  12.4  9.0  1.4  0.9  3.0  2.5  26.4
# 12  0.7  4.8   5.4  5.1  1.3  0.5  3.1  1.8  25.9
# 13  0.5  3.2   3.7  6.2  1.0  0.5  1.7  2.2  25.9
# 14  0.9  6.4   7.3  8.3  1.3  0.5  3.5  1.1  25.7
#
#                           Awards
# 0                             AS
# 1           MVP-3,CPOY-6,AS,NBA1
# 2   MVP-4,DPOY-9,CPOY-12,AS,NBA1
# 3    MVP-2,DPOY-7,CPOY-3,AS,NBA1
# 4           MVP-5,CPOY-5,AS,NBA2
# 5                        AS,NBA3
# 6                  MVP-9,AS,NBA2
# 7           MVP-6,CPOY-9,AS,NBA1
# 8                        CPOY-12
# 9                             AS
# 10                CPOY-1,AS,NBA3
# 11          MVP-1,CPOY-4,AS,NBA1
# 12          MVP-7,CPOY-8,AS,NBA2
# 13                      MIP-1,AS
# 14               CPOY-10,AS,NBA3
#
# [15 rows x 31 columns]
